# %% [markdown]
# #Data Collection

# %%
#Import libraries
import numpy as np
import pandas as pd

# %%
#Load Data
data = pd.read_csv("Diabetes_data.csv")

data
# Out:
#      Pregnancies    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0  148.00000           72.0            NaN        0  33.6
# 1            1.0   85.00000           66.0            NaN        0  26.6
# 2            8.0  183.00000           64.0            0.0        0  23.3
# 3            1.0   89.00000           66.0           23.0       94  28.1
# 4            0.0  120.81201           40.0           35.0      168  43.1
# ..           ...        ...            ...            ...      ...   ...
# 680         10.0  101.00000           76.0           48.0      180  32.9
# 681          2.0  122.00000           70.0           27.0        0  36.8
# 682          5.0  121.00000           72.0           23.0      112  26.2
# 683          1.0  126.00000           60.0            0.0        0  30.1
# 684          1.0   93.00000           70.0           31.0        0  30.4
#
#      DiabetesPedigreeFunction  Age       Outcome
# ...

# %% [markdown]
# #Let’s Discover Our Data

# %%
# (number_of_rows, number_of_columns)

# %%
data.head()
# Out:
#    Pregnancies    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0  148.00000           72.0            NaN        0  33.6
# 1          1.0   85.00000           66.0            NaN        0  26.6
# 2          8.0  183.00000           64.0            0.0        0  23.3
# 3          1.0   89.00000           66.0           23.0       94  28.1
# 4          0.0  120.81201           40.0           35.0      168  43.1
#
#    DiabetesPedigreeFunction  Age       Outcome
# 0                     0.627   50  Non-Diabetic
# 1                     0.351   31      Diabetic
# 2                     0.672   32  Non-Diabetic
# 3                     0.167   21      Diabetic
# 4                     2.288   33  Non-Diabetic

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 680         10.0    101.0           76.0           48.0      180  32.9
# 681          2.0    122.0           70.0           27.0        0  36.8
# 682          5.0    121.0           72.0           23.0      112  26.2
# 683          1.0    126.0           60.0            0.0        0  30.1
# 684          1.0     93.0           70.0           31.0        0  30.4
#
#      DiabetesPedigreeFunction  Age       Outcome
# 680                     0.171   63      Diabetic
# 681                     0.340   27      Diabetic
# 682                     0.245   30      Diabetic
# 683                     0.349   47  Non-Diabetic
# 684                     0.315   23      Diabetic

# %%
data.sample(5)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 589          1.0    199.0           76.0           43.0        0  42.9
# 262          0.0    161.0           50.0            0.0        0  21.9
# 317          3.0     90.0           78.0            0.0        0  42.7
# 143          4.0    151.0           90.0           38.0        0  29.7
# 390          1.0     97.0           70.0           15.0        0  18.2
#
#      DiabetesPedigreeFunction  Age       Outcome
# 589                     1.394   22  Non-Diabetic
# 262                     0.254   65      Diabetic
# 317                     0.559   21      Diabetic
# 143                     0.294   36      Diabetic
# 390                     0.147   21      Diabetic

# %%
numerical_features = data.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_features = data.select_dtypes(include=['object']).columns.tolist()

print(f"Numerical Features: {numerical_features}")
print(f"Categorical Features: {categorical_features}")
# Out:
# Numerical Features: ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age']
# Categorical Features: ['Outcome']

# %% [markdown]
# #Data Cleaning

# %%
data.isnull().sum() # Identifying Missing Data
# Out:
# Pregnancies                 2
# Glucose                     0
# BloodPressure               0
# SkinThickness               2
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# Remplacer les valeurs manquantes avec la valeur moyenne
data["Pregnancies"].fillna(data["Pregnancies"].mean() , inplace = True)
data["SkinThickness"].fillna(data["SkinThickness"].mean() , inplace = True)
# Out:
# <ipython-input-17-94c62aaae74c>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["Pregnancies"].fillna(data["Pregnancies"].mean() , inplace = True)
# <ipython-input-17-94c62aaae74c>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
# Verification

# %% [markdown]
# #Data Transformation

# %%
# Data Transformation with Label Encoder
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
data["Outcome"] = encoder.fit_transform(data["Outcome"])

data
# Out:
#      Pregnancies    Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6.0  148.00000           72.0      20.831625        0  33.6
# 1            1.0   85.00000           66.0      20.831625        0  26.6
# 2            8.0  183.00000           64.0       0.000000        0  23.3
# 3            1.0   89.00000           66.0      23.000000       94  28.1
# 4            0.0  120.81201           40.0      35.000000      168  43.1
# ..           ...        ...            ...            ...      ...   ...
# 680         10.0  101.00000           76.0      48.000000      180  32.9
# 681          2.0  122.00000           70.0      27.000000        0  36.8
# 682          5.0  121.00000           72.0      23.000000      112  26.2
# 683          1.0  126.00000           60.0       0.000000        0  30.1
# 684          1.0   93.00000           70.0      31.000000        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# #Data Visualization

# %%
#Importation les libraries matplotlib et seaborn
import matplotlib.pyplot as plt
import seaborn as sns

#Detecting outliers


# Boxplot pour la colonne "Tempo"
plt.figure(figsize=(15, 6))
# ------------
plt.title("Outliers")
plt.show()

# %% [markdown]
# #Feature Selection & Splitting Data

# %%
# Feature Extraction
x = data.iloc[ : , :-1]
y = data.iloc[ : , -1]


from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

print("X_train:\n", x_train)
print("X_test:\n", x_test)
print("Y_train:\n", y_train)
print("Y_test:\n", y_test)
# Out:
# X_train:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 550          2.0     68.0           62.0           13.0       15  20.1
# 563          0.0    102.0           78.0           40.0       90  34.5
# 481          3.0    129.0           92.0           49.0      155  36.4
# 208          4.0    122.0           68.0            0.0        0  35.0
# 227         12.0     92.0           62.0            7.0      258  27.6
# ..           ...      ...            ...            ...      ...   ...
# 71           7.0     83.0           78.0           26.0       71  29.3
# 106          0.0    162.0           76.0           56.0      100  53.2
# 270          3.0    150.0           76.0            0.0        0  21.0
# 435          4.0     99.0           72.0           17.0        0  25.6
# 102          5.0    124.0           74.0            0.0        0  34.0
#
#      DiabetesPedigreeFunction  Age
# 550                     0.257   23
# ...

# %% [markdown]
# #Model Selection And Training

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
classifier = SVC()
#training the support vector Machine Classifier
classifier.fit(x_train, y_train)
# Out:
# SVC()

# %%
# accuracy score on the test data
y_pred = classifier.predict(x_test)
print("Accuracy = ", accuracy_score(y_pred,y_test))
# Out:
# Accuracy =  0.7664233576642335

# %% [markdown]
# #Test the model

# %%
new_data = [
    (2.0  ,  102.0    ,       86.0  ,         36.0  ,    120 , 45.5,0.127  , 23 )
]

new_data_df = pd.DataFrame(new_data)
new_data_prediction_svm = classifier.predict(new_data_df)

print("SVM Predictions: ")

if new_data_prediction_svm== 1:
      print("Diabétique")
elif new_data_prediction_svm== 0:
      print("Non diabétique")
# Out:
# SVM Predictions:
# Non diabétique
